# %%
import torch
import pandas as pd
from torch import nn, optim
from torch.autograd.variable import Variable
from torchvision import transforms, datasets
from data_treatment import DataSet, DataAtts
from discriminator import *
from generator import *
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import glob

# %%
# Noise
def noise(size):
    n = Variable(torch.randn(size, 100))
    if torch.cuda.is_available(): 
        return n.cuda() 
    return n

# %%
files_dropdown = widgets.Dropdown(
    options=glob.glob("original_data/*.csv"),
    description='File:',
    value = 'original_data/diabetes_escalonated.csv',
    disabled=False,
)
display(files_dropdown)
# Out:
# Dropdown(description='File:', options=('original_data/diabetes_escalonated.csv', 'original_data/data.csv', 'or…

# %%
file_name=files_dropdown.value
dataAtts = DataAtts(file_name)

# %%
def train_generator(optimizer, fake_data):
    # 2. Train Generator
    # Reset gradients
    optimizer.zero_grad()
    # Sample noise and generate fake data
    prediction = discriminator(fake_data)
    # Calculate error and backpropagate
    error = loss(prediction, real_data_target(prediction.size(0)))
    error.backward()
    # Update weights with gradients
    optimizer.step()
    # Return error
    return error

def train_discriminator(optimizer, real_data, fake_data):
    # Reset gradients
    optimizer.zero_grad()
    
    # 1.1 Train on Real Data
    prediction_real = discriminator(real_data)
    # Calculate error and backpropagate
    error_real = loss(prediction_real, real_data_target(real_data.size(0)))
    error_real.backward()

    # 1.2 Train on Fake Data
    prediction_fake = discriminator(fake_data)
    # Calculate error and backpropagate
    error_fake = loss(prediction_fake, fake_data_target(real_data.size(0)))
    error_fake.backward()
    
    # 1.3 Update weights with gradients
    optimizer.step()
    
    # Return error
    return error_real + error_fake, prediction_real, prediction_fake

# %%
def real_data_target(size):
    '''
    Tensor containing ones, with shape = size
    '''
    data = Variable(torch.ones(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

def fake_data_target(size):
    '''
    Tensor containing zeros, with shape = size
    '''
    data = Variable(torch.zeros(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

# %%
lr = 0.0002
#lr= 0.0002
batch_size = 5
num_epochs = 106
print_interval = 10
loss = nn.BCELoss()

# %%
discriminator = DiscriminatorNet(dataAtts.class_len)
generator = GeneratorNet(dataAtts.class_len)
if torch.cuda.is_available():
    discriminator.cuda()
    generator.cuda()
d_optimizer = optim.Adam(discriminator.parameters(), lr=lr)
g_optimizer = optim.Adam(generator.parameters(), lr=lr)

# %%
d_error_plt = [0]
g_error_plt = [0]

generated_points = []

# %%
database = DataSet (csv_file=file_name, root_dir=".")

data_loader = torch.utils.data.DataLoader(database, batch_size=batch_size, shuffle=True)
num_batches = len(data_loader)

# %%
for epoch in range(num_epochs):
    print("Epoch ", epoch)

    for n_batch, real_batch in enumerate(data_loader):
        # 1. Train Discriminator
        real_data = Variable(real_batch).float()
        if torch.cuda.is_available(): 
            real_data = real_data.cuda()
        # Generate fake data
        fake_data = generator(noise(real_data.size(0))).detach()
        # Train D
        d_error, d_pred_real, d_pred_fake = train_discriminator(d_optimizer,
                                                                real_data, fake_data)

        # 2. Train Generator
        # Generate fake data
        fake_data = generator(noise(real_batch.size(0)))
        generated_points.append(fake_data)
        # Train G
        g_error = train_generator(g_optimizer, fake_data)

        # Display Progress

        #if (n_batch) % print_interval == 0:
    filename = "results/" + dataAtts.fname + "/" + str(epoch) + "_" + str(n_batch) + ".txt"
    print(filename)
    file = open(filename, "w")
    print("Discriminator error: ", d_error)
    print("Generator error: ", g_error)
    print("")

    file.write("Discriminator error: " + str(d_error) + "\n")
    file.write("Generator error: " + str(g_error) + "\n")
    file.write("Points: " + str(fake_data) + "\n\n\n")

    d_error_plt.append(d_error)
    g_error_plt.append(g_error)
        #     #display.clear_output(True)
        #     # Display Images
        #     test_images = generator(test_noise).data.cpu()
        #     logger.log_images(test_images, num_test_samples, epoch, n_batch, num_batches);
        #     # Display status Logs
        #     #logger.display_status(epoch, num_epochs, n_batch, num_batches, d_error, g_error, d_pred_real, d_pred_fake)
        # # Model Checkpoints
# Out:
# Epoch  0
# results/diabetes_escalonated/0_107.txt
# Discriminator error:  tensor(2.0641, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9702, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  1
# results/diabetes_escalonated/1_107.txt
# Discriminator error:  tensor(1.1974, grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2049, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2
# results/diabetes_escalonated/2_107.txt
# Discriminator error:  tensor(1.3745, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6844, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  3
# results/diabetes_escalonated/3_107.txt
# Discriminator error:  tensor(1.3459, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8369, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  4
# results/diabetes_escalonated/4_107.txt
# Discriminator error:  tensor(1.5805, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7174, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  5
# results/diabetes_escalonated/5_107.txt
# Discriminator error:  tensor(1.2623, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7913, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  6
# results/diabetes_escalonated/6_107.txt
# Discriminator error:  tensor(1.4062, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6151, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  7
# results/diabetes_escalonated/7_107.txt
# Discriminator error:  tensor(1.3281, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7110, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  8
# results/diabetes_escalonated/8_107.txt
# Discriminator error:  tensor(1.1390, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7722, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  9
# results/diabetes_escalonated/9_107.txt
# Discriminator error:  tensor(1.6051, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6125, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  10
# results/diabetes_escalonated/10_107.txt
# Discriminator error:  tensor(1.3854, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6746, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  11
# results/diabetes_escalonated/11_107.txt
# Discriminator error:  tensor(1.4185, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6878, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  12
# results/diabetes_escalonated/12_107.txt
# Discriminator error:  tensor(1.3825, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8076, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  13
# results/diabetes_escalonated/13_107.txt
# Discriminator error:  tensor(1.4726, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6932, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  14
# results/diabetes_escalonated/14_107.txt
# Discriminator error:  tensor(1.3430, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6997, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  15
# results/diabetes_escalonated/15_107.txt
# Discriminator error:  tensor(1.5421, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6554, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  16
# results/diabetes_escalonated/16_107.txt
# Discriminator error:  tensor(1.5321, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6723, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  17
# results/diabetes_escalonated/17_107.txt
# Discriminator error:  tensor(1.3653, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7816, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  18
# results/diabetes_escalonated/18_107.txt
# Discriminator error:  tensor(1.3895, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6536, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  19
# results/diabetes_escalonated/19_107.txt
# Discriminator error:  tensor(1.3347, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6661, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  20
# results/diabetes_escalonated/20_107.txt
# Discriminator error:  tensor(1.3817, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6569, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  21
# results/diabetes_escalonated/21_107.txt
# Discriminator error:  tensor(1.5338, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7044, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  22
# results/diabetes_escalonated/22_107.txt
# Discriminator error:  tensor(1.3495, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6513, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  23
# results/diabetes_escalonated/23_107.txt
# Discriminator error:  tensor(1.3422, grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5392, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  24
# results/diabetes_escalonated/24_107.txt
# Discriminator error:  tensor(1.3877, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6531, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  25
# results/diabetes_escalonated/25_107.txt
# Discriminator error:  tensor(1.2924, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6784, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  26
# results/diabetes_escalonated/26_107.txt
# Discriminator error:  tensor(1.3686, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8698, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  27
# results/diabetes_escalonated/27_107.txt
# Discriminator error:  tensor(1.3616, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6674, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  28
# results/diabetes_escalonated/28_107.txt
# Discriminator error:  tensor(1.4217, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7522, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  29
# results/diabetes_escalonated/29_107.txt
# Discriminator error:  tensor(1.3213, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6731, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  30
# results/diabetes_escalonated/30_107.txt
# Discriminator error:  tensor(1.4229, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6667, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  31
# results/diabetes_escalonated/31_107.txt
# Discriminator error:  tensor(1.3029, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7607, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  32
# results/diabetes_escalonated/32_107.txt
# Discriminator error:  tensor(1.3717, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8018, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  33
# results/diabetes_escalonated/33_107.txt
# Discriminator error:  tensor(1.3926, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7112, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  34
# results/diabetes_escalonated/34_107.txt
# Discriminator error:  tensor(1.3948, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6439, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  35
# results/diabetes_escalonated/35_107.txt
# Discriminator error:  tensor(1.4991, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7248, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  36
# results/diabetes_escalonated/36_107.txt
# Discriminator error:  tensor(1.4036, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6133, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  37
# results/diabetes_escalonated/37_107.txt
# Discriminator error:  tensor(1.3417, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6854, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  38
# results/diabetes_escalonated/38_107.txt
# Discriminator error:  tensor(1.3896, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6941, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  39
# results/diabetes_escalonated/39_107.txt
# Discriminator error:  tensor(1.3410, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7495, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  40
# results/diabetes_escalonated/40_107.txt
# Discriminator error:  tensor(1.4145, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6907, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  41
# results/diabetes_escalonated/41_107.txt
# Discriminator error:  tensor(1.3279, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6998, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  42
# results/diabetes_escalonated/42_107.txt
# Discriminator error:  tensor(1.3951, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7034, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  43
# results/diabetes_escalonated/43_107.txt
# Discriminator error:  tensor(1.3914, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7700, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  44
# results/diabetes_escalonated/44_107.txt
# Discriminator error:  tensor(1.3652, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7918, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  45
# results/diabetes_escalonated/45_107.txt
# Discriminator error:  tensor(1.4254, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7436, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  46
# results/diabetes_escalonated/46_107.txt
# Discriminator error:  tensor(1.4301, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7705, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  47
# results/diabetes_escalonated/47_107.txt
# Discriminator error:  tensor(1.4202, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6769, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  48
# results/diabetes_escalonated/48_107.txt
# Discriminator error:  tensor(1.4045, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6532, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  49
# results/diabetes_escalonated/49_107.txt
# Discriminator error:  tensor(1.5066, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6774, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  50
# results/diabetes_escalonated/50_107.txt
# Discriminator error:  tensor(1.3821, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7435, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  51
# results/diabetes_escalonated/51_107.txt
# Discriminator error:  tensor(1.4527, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6756, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  52
# results/diabetes_escalonated/52_107.txt
# Discriminator error:  tensor(1.4502, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7720, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  53
# results/diabetes_escalonated/53_107.txt
# Discriminator error:  tensor(1.2733, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7634, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  54
# results/diabetes_escalonated/54_107.txt
# Discriminator error:  tensor(1.2885, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6820, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  55
# results/diabetes_escalonated/55_107.txt
# Discriminator error:  tensor(1.2891, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6777, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  56
# results/diabetes_escalonated/56_107.txt
# Discriminator error:  tensor(1.3266, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8273, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  57
# results/diabetes_escalonated/57_107.txt
# Discriminator error:  tensor(1.4450, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5904, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  58
# results/diabetes_escalonated/58_107.txt
# Discriminator error:  tensor(1.3807, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7401, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  59
# results/diabetes_escalonated/59_107.txt
# Discriminator error:  tensor(1.3810, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6283, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  60
# results/diabetes_escalonated/60_107.txt
# Discriminator error:  tensor(1.3933, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7798, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  61
# results/diabetes_escalonated/61_107.txt
# Discriminator error:  tensor(1.4207, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6378, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  62
# results/diabetes_escalonated/62_107.txt
# Discriminator error:  tensor(1.3858, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7818, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  63
# results/diabetes_escalonated/63_107.txt
# Discriminator error:  tensor(1.3668, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5927, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  64
# results/diabetes_escalonated/64_107.txt
# Discriminator error:  tensor(1.3824, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7523, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  65
# results/diabetes_escalonated/65_107.txt
# Discriminator error:  tensor(1.5890, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6170, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  66
# results/diabetes_escalonated/66_107.txt
# Discriminator error:  tensor(1.5525, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7877, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  67
# results/diabetes_escalonated/67_107.txt
# Discriminator error:  tensor(1.4247, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6511, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  68
# results/diabetes_escalonated/68_107.txt
# Discriminator error:  tensor(1.3939, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8233, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  69
# results/diabetes_escalonated/69_107.txt
# Discriminator error:  tensor(1.4859, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6239, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  70
# results/diabetes_escalonated/70_107.txt
# Discriminator error:  tensor(1.4159, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8089, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  71
# results/diabetes_escalonated/71_107.txt
# Discriminator error:  tensor(1.3314, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6281, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  72
# results/diabetes_escalonated/72_107.txt
# Discriminator error:  tensor(1.4048, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6827, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  73
# results/diabetes_escalonated/73_107.txt
# Discriminator error:  tensor(1.3218, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6312, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  74
# results/diabetes_escalonated/74_107.txt
# Discriminator error:  tensor(1.3451, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7928, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  75
# results/diabetes_escalonated/75_107.txt
# Discriminator error:  tensor(1.4353, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8723, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  76
# results/diabetes_escalonated/76_107.txt
# Discriminator error:  tensor(1.3822, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7395, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  77
# results/diabetes_escalonated/77_107.txt
# Discriminator error:  tensor(1.1195, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6893, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  78
# results/diabetes_escalonated/78_107.txt
# Discriminator error:  tensor(1.2318, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7641, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  79
# results/diabetes_escalonated/79_107.txt
# Discriminator error:  tensor(2.0625, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4941, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  80
# results/diabetes_escalonated/80_107.txt
# Discriminator error:  tensor(1.3834, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6189, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  81
# results/diabetes_escalonated/81_107.txt
# Discriminator error:  tensor(1.9804, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6425, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  82
# results/diabetes_escalonated/82_107.txt
# Discriminator error:  tensor(1.4415, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6555, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  83
# results/diabetes_escalonated/83_107.txt
# Discriminator error:  tensor(1.5684, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7897, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  84
# results/diabetes_escalonated/84_107.txt
# Discriminator error:  tensor(1.0176, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8942, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  85
# results/diabetes_escalonated/85_107.txt
# Discriminator error:  tensor(1.3471, grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8976, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  86
# results/diabetes_escalonated/86_107.txt
# Discriminator error:  tensor(1.3618, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8981, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  87
# results/diabetes_escalonated/87_107.txt
# Discriminator error:  tensor(1.4518, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8603, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  88
# results/diabetes_escalonated/88_107.txt
# Discriminator error:  tensor(0.9970, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8727, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  89
# results/diabetes_escalonated/89_107.txt
# Discriminator error:  tensor(1.4125, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6860, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  90
# results/diabetes_escalonated/90_107.txt
# Discriminator error:  tensor(1.0658, grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1643, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  91
# results/diabetes_escalonated/91_107.txt
# Discriminator error:  tensor(0.7670, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7796, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  92
# results/diabetes_escalonated/92_107.txt
# Discriminator error:  tensor(1.3816, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7571, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  93
# results/diabetes_escalonated/93_107.txt
# Discriminator error:  tensor(1.7080, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9132, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  94
# results/diabetes_escalonated/94_107.txt
# Discriminator error:  tensor(1.4493, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8840, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  95
# results/diabetes_escalonated/95_107.txt
# Discriminator error:  tensor(1.1034, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8254, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  96
# results/diabetes_escalonated/96_107.txt
# Discriminator error:  tensor(1.3452, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8110, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  97
# results/diabetes_escalonated/97_107.txt
# Discriminator error:  tensor(1.2170, grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0021, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  98
# results/diabetes_escalonated/98_107.txt
# Discriminator error:  tensor(1.5669, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8851, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  99
# results/diabetes_escalonated/99_107.txt
# Discriminator error:  tensor(1.5895, grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5432, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  100
# results/diabetes_escalonated/100_107.txt
# Discriminator error:  tensor(0.9325, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8124, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  101
# results/diabetes_escalonated/101_107.txt
# Discriminator error:  tensor(1.5180, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8683, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  102
# results/diabetes_escalonated/102_107.txt
# Discriminator error:  tensor(1.0549, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8718, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  103
# results/diabetes_escalonated/103_107.txt
# Discriminator error:  tensor(0.8135, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7377, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  104
# results/diabetes_escalonated/104_107.txt
# Discriminator error:  tensor(0.7362, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5830, grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  105
# results/diabetes_escalonated/105_107.txt
# Discriminator error:  tensor(1.4033, grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9397, grad_fn=<BinaryCrossEntropyBackward>)

# %%
print(epoch)
torch.save({
            'epoch': epoch,
            'model_state_dict': generator.state_dict(),
            'optimizer_state_dict': g_optimizer.state_dict(),
            'loss': loss
            }, "models/generator" + dataAtts.fname + "_" + str(epoch) + ".pt")

torch.save({
            'epoch': epoch,
            'model_state_dict': discriminator.state_dict(),
            'optimizer_state_dict': d_optimizer.state_dict(),
            'loss': loss
            }, "models/discriminator" + dataAtts.fname + "_" + str(epoch) + ".pt")
# Out:
# 105
# //anaconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type BCELoss. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
plt.plot(d_error_plt, 'b')
plt.plot(g_error_plt, 'r')
filename = "results/" + dataAtts.fname + "/" + "error_growth.txt"
file = open(filename, "w")
file.write("Discriminator error: " + str(d_error_plt) + "\n")
file.write("\n\n\n")
file.write("Generator error: " + str(g_error_plt) + "\n")
file.close()

plt.savefig('images/'+ dataAtts.fname + "/"+ 'error.png')
plt.show()
plt.clf()
